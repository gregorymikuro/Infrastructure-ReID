# %% [markdown]
# <a href="https://colab.research.google.com/github/gregorymikuro/Infrastructure-ReID/blob/main/data_download.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U kagglehub

import kagglehub
from google.colab import drive

# Log in to Kaggle
kagglehub.login()

# Mount Google Drive
drive.mount("/content/drive")

# Download location
save_dir = "/content/drive/MyDrive/Urban_ReID/data"

# Clear existing contents and download/extract again
path = kagglehub.competition_download(
    "urban-elements-re-id-challenge-2026",
    output_dir=save_dir,
    force_download=True
)

print("Dataset saved and extracted to:", path)
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ...
# 100%|██████████| 119M/119M [00:01<00:00, 73.0MB/s]
# Extracting files...
# Dataset saved and extracted to: /content/drive/MyDrive/Urban_ReID/data
